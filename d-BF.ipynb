# %%
import os
# import json
import math
import torch
from itertools import product
from dataclasses import dataclass, field

from gamesopt.attacks import Attack
from gamesopt.optimizer import Optimizer
from gamesopt.aggregator import Aggregator
from gamesopt.games import Game, create_matrix, create_bias
from gamesopt.train_distributed import train

# %matplotlib widget
# %matplotlib inline
# %load_ext autoreload
# %autoreload 1

# %%
os.environ['MLFLOW_VERBOSE'] = 'True'
os.environ['MLFLOW_EXPERIMENT_NAME'] = os.path.basename(os.getcwd())

# %%
# class Config(BaseConfig):
@dataclass
class Config():
    n_iter: int = 6001

    n_peers: int = 100
    n_byzan: int = 20

    # game: Game = Game.Quadratic
    game: Game = field(default_factory=lambda: Game.Quadratic)
    num_samples: int = 1000
    dim: int = 25
    with_bias: bool = True
    mu: float = 1e-1
    ell: float = 1e3

    optimizer: Optimizer = None
    batch_size: int = None
    lr: float = 1/2/ell/15
    alpha: float = None
    sigmaC: float = None

    attack: Attack = None
    n_attacking: int = None
    attack_param: float = None

    use_bucketing: bool = None
    bucketing_s: int = 2

    aggregator: Aggregator = None
    aggregator_param_a: int = 10  # trimmed_mean_b=10; krum_m=2; ,clipping_n_iter=3 clipping_tau=10
    aggregator_param_b: float = 0.1 # rfa_T=10,rfa_nu=0.1    , 0.1)  # rfa_T=10,rfa_nu=0.1

# %%
@dataclass
class Data():
    def __init__(self, config):
        self.matrix = create_matrix(config.dim, config.num_samples,
                                    config.mu, config.ell,
                                    with_bias=config.with_bias)
        self.bias = create_bias(config.dim, config.num_samples,
                                with_bias=config.with_bias)
        self.true = torch.linalg.solve(self.matrix.mean(dim=0),
                                       -self.bias.mean(dim=0))
        self.players = self.true + .1/math.sqrt(2 * config.dim)

# %%
base_config = Config()
data = Data(base_config)
# base_config_items = set(base_config.__dict__.items())

# %%
for at, bs in product([Attack.BF],
                          # [1e1, 1e2, 1e3, 1e4],
                          [1, 10, 100]):

    # SGDA
    config = Config(attack=at, batch_size=bs)
    config.optimizer = Optimizer.SGDA
    config.aggregator = Aggregator.Mean
    config.n_attacking = config.n_byzan
    # config_items = set(config.__dict__.items())
    os.environ['MLFLOW_RUN_TAG'] = 'RA'
    os.environ['MLFLOW_RUN_NAME'] = 'SGDA'
    os.environ['MLFLOW_RUN_TITLE'] = '%s, bs=%i' % (at, bs)
    # json.dumps(dict(sorted(config_items - base_config_items)))
    train(config, data)

    # SGDARA
    config = Config(attack=at, batch_size=bs)
    config.optimizer = Optimizer.SGDARA
    config.aggregator = Aggregator.RFA
    config.use_bucketing = True
    config.n_attacking = config.n_byzan
    os.environ['MLFLOW_RUN_TAG'] = 'RA'
    os.environ['MLFLOW_RUN_NAME'] = 'SGDARA'
    os.environ['MLFLOW_RUN_TITLE'] = '%s, bs=%i' % (at, bs)
    train(config, data)

    # MSGDARA
    config = Config(attack=at, batch_size=bs)
    config.optimizer = Optimizer.MSGDARA
    config.alpha = 0.1
    config.aggregator = Aggregator.RFA
    config.use_bucketing = True
    config.n_attacking = config.n_byzan
    os.environ['MLFLOW_RUN_TAG'] = 'RA M'
    os.environ['MLFLOW_RUN_NAME'] = 'MSGDARA'
    os.environ['MLFLOW_RUN_TITLE'] = '%s, bs=%i' % (at, bs)
    train(config, data)

    # SEGRA
    config = Config(attack=at, batch_size=bs)
    config.n_iter = int(config.n_iter / 2) + 1
    config.optimizer = Optimizer.SEGRA
    config.aggregator = Aggregator.RFA
    config.use_bucketing = True
    config.n_attacking = config.n_byzan
    os.environ['MLFLOW_RUN_TAG'] = 'RA'
    os.environ['MLFLOW_RUN_NAME'] = 'SEGRA'
    os.environ['MLFLOW_RUN_TITLE'] = '%s, bs=%i' % (at, bs)
    train(config, data)

    # RDEG
    config = Config(attack=at, batch_size=bs)
    config.n_iter = int(config.n_iter / 2) + 1
    config.optimizer = Optimizer.RDEG
    config.aggregator = Aggregator.UnivariateTM
    config.n_attacking = config.n_byzan
    os.environ['MLFLOW_RUN_TAG'] = 'RA'
    os.environ['MLFLOW_RUN_NAME'] = 'RDEG'
    os.environ['MLFLOW_RUN_TITLE'] = '%s, bs=%i' % (at, bs)
    train(config, data)

    # SGDACC
    config = Config(attack=at, batch_size=bs)
    config.n_iter = config.n_iter * 2 - 1
    config.optimizer = Optimizer.SGDACC
    config.aggregator = Aggregator.Mean
    config.sigmaC = 100.
    config.n_attacking = 1
    os.environ['MLFLOW_RUN_TAG'] = 'CC'
    os.environ['MLFLOW_RUN_NAME'] = 'SGDACC'
    os.environ['MLFLOW_RUN_TITLE'] = '%s, bs=%i' % (at, bs)
    train(config, data)

    # SEGCC
    config = Config(attack=at, batch_size=bs)
    config.n_iter = config.n_iter + 1
    config.optimizer = Optimizer.SEGCC
    config.aggregator = Aggregator.Mean
    config.sigmaC = 100.
    config.n_attacking = 1
    os.environ['MLFLOW_RUN_TAG'] = 'CC'
    os.environ['MLFLOW_RUN_NAME'] = 'SEGCC'
    os.environ['MLFLOW_RUN_TITLE'] = '%s, bs=%i' % (at, bs)
    train(config, data)
# Out:
# Trying port 37555
# Trying port 40809
# Trying port 10837
# Trying port 26135
# 2325
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [9], line 50
#      48 os.environ['MLFLOW_RUN_NAME'] = 'SEGRA'
#      49 os.environ['MLFLOW_RUN_TITLE'] = '%s, bs=%i' % (at, bs)
# ---> 50 train(config, data)
#      52 # RDEG
#      53 config = Config(attack=at, batch_size=bs)
#
# File ~/sgda-ra/gamesopt/train_distributed.py:97, in train(config, data)
#      95 print("Trying port %s" % port)
#      96 try:
# ---> 97     mp.spawn(_train,
#      98              args=(port, config, data),
#      99              # nprocs=config['n_peers'],
#     100              # nprocs=config.n_peers,
#     101              nprocs=nprocs,
#     102              join=True)
#     103     break
#     104 except PortNotAvailableError:
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py:230, in spawn(fn, args, nprocs, join, daemon, start_method)
#     226     msg = ('This method only supports start_method=spawn (got: %s).\n'
#     227            'To use a different start_method use:\n\t\t'
#     228            ' torch.multiprocessing.start_processes(...)' % start_method)
#     229     warnings.warn(msg)
# --> 230 return start_processes(fn, args, nprocs, join, daemon, start_method='spawn')
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py:188, in start_processes(fn, args, nprocs, join, daemon, start_method)
#     185     return context
#     187 # Loop on join until it returns True or raises an exception.
# --> 188 while not context.join():
#     189     pass
#
# File ~/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py:99, in ProcessContext.join(self, timeout)
#      96     return True
#      98 # Wait for any process to fail or all of them to succeed.
# ---> 99 ready = multiprocessing.connection.wait(
#     100     self.sentinels.keys(),
#     101     timeout=timeout,
#     102 )
#     104 error_index = None
#     105 for sentinel in ready:
#
# File ~/miniconda3/lib/python3.9/multiprocessing/connection.py:936, in wait(object_list, timeout)
#     933     deadline = time.monotonic() + timeout
#     935 while True:
# --> 936     ready = selector.select(timeout)
#     937     if ready:
#     938         return [key.fileobj for (key, events) in ready]
#
# File ~/miniconda3/lib/python3.9/selectors.py:416, in _PollLikeSelector.select(self, timeout)
#     414 ready = []
#     415 try:
# --> 416     fd_event_list = self._selector.poll(timeout)
#     417 except InterruptedError:
#     418     return ready
#
# KeyboardInterrupt:
# Process SpawnProcess-402:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:35724
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-403:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:1728
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-405:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:54978
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-409:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:399
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-417:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:30367
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-433:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:11699
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-404:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:2466
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-406:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:9088
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-407:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:50590
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-410:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:18336
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-411:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:47323
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-413:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:34712
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-418:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:15237
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-419:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:8610
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-421:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:34200
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-434:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:6055
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-425:
# Process SpawnProcess-465:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:23969
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:45483
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-435:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:19859
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-437:
# Traceback (most recent call last):
# Process SpawnProcess-408:
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:60032
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:36231
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-412:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:3492
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-415:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:10647
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-414:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:41622
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-420:
# Process SpawnProcess-441:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# Traceback (most recent call last):
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:35044
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
# Traceback (most recent call last):
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:26335
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-423:
# Process SpawnProcess-422:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:32652
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:35010
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-426:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:57750
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-449:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:11683
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-427:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:54707
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-436:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:32157
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-466:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:12716
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-439:
# Process SpawnProcess-438:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:14513
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:6545
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-467:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:10675
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-429:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:25499
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-442:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:2981
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-469:
# Traceback (most recent call last):
# ...
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-448:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:925
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-461:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:14744
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-492:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:10117
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-480:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:42649
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-493:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:16811
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-456:
# Process SpawnProcess-462:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:62876
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:42730
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-488:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:18846
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-494:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:134
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-464:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:14741
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-463:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:59033
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-496:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.0.1]:17112
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
# Process SpawnProcess-495:
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
#   File "/home/nazya/sgda-ra/gamesopt/train_distributed.py", line 72, in _train
#     optimizer.step()
#   File "/home/nazya/sgda-ra/gamesopt/optimizer/distributed.py", line 136, in step
#     dist.broadcast(self.game.players, src=self.game.master_node)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/distributed/distributed_c10d.py", line 1084, in broadcast
#     work.wait()
# RuntimeError: [/pytorch/third_party/gloo/gloo/transport/tcp/pair.cc:598] Connection closed by peer [127.0.1.1]:1440
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/nazya/miniconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/nazya/miniconda3/lib/python3.9/site-packages/torch/multiprocessing/spawn.py", line 59, in _wrap
#     fn(i, *args)
# KeyboardInterrupt
